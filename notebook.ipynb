# %%
import requests
import json
import csv
import os
def youtube_search(api_key, channel_id, max_results=500):
    base_url = "https://www.googleapis.com/youtube/v3/search"
    
    params = {
        'key': api_key,
        'channelId': channel_id,
        'part': 'snippet,id',
        'order': 'date',
        'maxResults': max_results
    }
    
    try:
        response = requests.get(base_url, params=params)
        response.raise_for_status()  # Raise an exception for bad status codes
        
        return response.json()
    
    except requests.exceptions.RequestException as e:
        print(f"An error occurred: {e}")
        return None

from dotenv import load_dotenv
load_dotenv()
api_key = os.getenv("YT_DATA_API")
channel_id = "UC0-VH8rqv7WkqdvmhgdN2-A"

results = youtube_search(api_key, channel_id)
print(type(results))
print(results)

file_path = "./Data/raw_data.json"

# Write the dictionary to a JSON file
with open(file_path, "w") as json_file:
    json.dump(results, json_file, indent=4)

print(f"Data has been saved to {file_path}")
# Out:
# <class 'dict'>
# {'kind': 'youtube#searchListResponse', 'etag': 'UptRaLUjj-A4azJo8kogrR-w3_o', 'nextPageToken': 'CDIQAA', 'regionCode': 'IN', 'pageInfo': {'totalResults': 204, 'resultsPerPage': 50}, 'items': [{'kind': 'youtube#searchResult', 'etag': 'hZnJHUrNZOaJ1sGJozWnXXBLN1A', 'id': {'kind': 'youtube#video', 'videoId': 'E0rrOtP-rtU'}, 'snippet': {'publishedAt': '2024-06-26T06:10:22Z', 'channelId': 'UC0-VH8rqv7WkqdvmhgdN2-A', 'title': 'अगर आत्माओं की समस्या हैं तो अभी ठीक करें | #shorts', 'description': 'आपको किसी भी प्रकार की आत्माओं की समस्या हैं तो आप स्वामी आनंद ...', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/E0rrOtP-rtU/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/E0rrOtP-rtU/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/E0rrOtP-rtU/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'Ojas Healing', 'liveBroadcastContent': 'none', 'publishTime': '2024-06-26T06:10:22Z'}}, {'kind': 'youtube#searchResult', 'etag': '7_n5QcTqOUzBfqStHnHAziMD5WU', 'id': {'kind': 'youtube#video', 'videoId': '8gpXOVj4S6c'}, 'snippet': {'publishedAt': '2024-06-23T03:10:08Z', 'channelId': 'UC0-VH8rqv7WkqdvmhgdN2-A', 'title': 'पहले से तैयारी करें - सफलता के लिए सेल्फ हीलिंग कोर्स #shorts', 'description': 'पहले से तैयारी करें| जीवन में तकलीफ आएं तब यानी आग लगे तब कुआँ खोदने ...', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/8gpXOVj4S6c/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/8gpXOVj4S6c/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/8gpXOVj4S6c/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'Ojas Healing', 'liveBroadcastContent': 'none', 'publishTime': '2024-06-23T03:10:08Z'}}, {'kind': 'youtube#searchResult', 'etag': 'tDR5xhBa5ZFy9TmGHeBG79xr_MA', 'id': {'kind': 'youtube#video', 'videoId': 'Tro7p-a-WJ8'}, 'snippet': {'publishedAt': '2024-06-19T09:36:25Z', 'channelId': 'UC0-VH8rqv7WkqdvmhgdN2-A', 'title': 'क्या आपको लगता हैं की मेरी प्रगति रुक गई हैं? #shorts', 'description': 'अथर्ववेद की विधियाँ सीखें और अपना जीवन ठीक करें| आपका जीवन सफ़ल ...', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Tro7p-a-WJ8/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/Tro7p-a-WJ8/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/Tro7p-a-WJ8/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'Ojas Healing', 'liveBroadcastContent': 'none', 'publishTime': '2024-06-19T09:36:25Z'}}, {'kind': 'youtube#searchResult', 'etag': 'p972Ukj_FxDr9rzVEOuAYhnelNc', 'id': {'kind': 'youtube#video', 'videoId': '-NZY54lQcyw'}, 'snippet': {'publishedAt': '2024-06-15T14:30:00Z', 'channelId': 'UC0-VH8rqv7WkqdvmhgdN2-A', 'title': 'ध्यान में अनुभव ना होना आम बात हैं? | Is it common to have no experience in meditation? #shorts', 'description': 'ध्यान में अनुभव क्यों नहीं होते? मैं कहाँ गलती करता हूँ? ध्यान में ...', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/-NZY54lQcyw/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/-NZY54lQcyw/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/-NZY54lQcyw/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'Ojas Healing', 'liveBroadcastContent': 'none', 'publishTime': '2024-06-15T14:30:00Z'}}, {'kind': 'youtube#searchResult', 'etag': 'MLzwfb3QOg11lT5tGYwJlZBKt9A', 'id': {'kind': 'youtube#video', 'videoId': 'OmCf-xa23Nw'}, 'snippet': {'publishedAt': '2024-06-14T14:30:12Z', 'channelId': 'UC0-VH8rqv7WkqdvmhgdN2-A', 'title': 'क्या लकी स्टोन काम करते हैं? | Does stone really works? #shorts', 'description': 'कौनसा स्टोन पहेनना आपके लिए सब से अच्छा होगा? . . . . . . . . . . . . . . . . . . . . . . . . . . . Tags: ...', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/OmCf-xa23Nw/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/OmC ...
# Data has been saved to ./Data/raw_data.json

# %%
items = results['items']

# %%
len(items)
# Out:
# 50

# %%
header = ['Video ID', 'Published At', 'Channel ID', 'Title', 'Description', 'Channel Title', 'Default Thumbnail URL', 'Medium Thumbnail URL', 'High Thumbnail URL']

# Creating the CSV file
with open('youtube_videos.csv', 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(header)

    # Loop through items and write to CSV
    for item in items:
        # Check if 'videoId' exists
        if 'videoId' in item['id']:
            video_id = item['id']['videoId']
        else:
            continue  # Skip the item if 'videoId' is not found
        
        snippet = item['snippet']
        published_at = snippet['publishedAt']
        channel_id = snippet['channelId']
        title = snippet['title']
        description = snippet['description']
        channel_title = snippet['channelTitle']
        default_thumbnail_url = snippet['thumbnails']['default']['url']
        medium_thumbnail_url = snippet['thumbnails']['medium']['url']
        high_thumbnail_url = snippet['thumbnails']['high']['url']

        writer.writerow([video_id, published_at, channel_id, title, description, channel_title, default_thumbnail_url, medium_thumbnail_url, high_thumbnail_url])

print("CSV file created successfully.")
# Out:
# CSV file created successfully.
